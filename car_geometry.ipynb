# %% [markdown]
# <a href="https://colab.research.google.com/github/Jenicisprakash/machine-learning/blob/main/car_geometry.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from shapely.geometry import Point, Polygon

# %%
top = Polygon([(0,1),(0,2),(2,2),(2,1)])
bottom = Polygon([(-1,0),(-1,1),(4,1),(4,0)])
wheel_front = Point(0,-0.5).buffer(0.5)
wheel_rear = Point(3,-0.5).buffer(0.5)

# %%
car = top.union(bottom).union(wheel_front).union(wheel_rear)
car
# Out:
# <MULTIPOLYGON (((2 1, 4 1, 4 0, 3 0, 0 0, -1 0, -1 1, 0 1, 0 2, 2 2, 2 1)), ...>

# %%
print("Circumfrence :",car.length)
print("Area :",car.area)
# Out:
# Circumfrence : 20.28066231390951
# Area : 8.56827424527297
